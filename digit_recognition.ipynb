# %% [markdown]
# 自分のKaggleのjsonファイルをアップロードする

# %%
from google.colab import files
files.upload()

# %% [markdown]
# 今回で使うファイルをKaggleからダウンロードします

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/

# !pip install kaggle

# !chmod 600 /root/.kaggle/kaggle.json

# !kaggle competitions download -c digit-recognizer
# Out:
# Collecting kaggle
#   Downloading https://files.pythonhosted.org/packages/c6/78/832b9a9ec6b3baf8ec566e1f0a695f2fd08d2c94a6797257a106304bfc3c/kaggle-1.4.7.1.tar.gz (52kB)
#     100% |████████████████████████████████| 61kB 2.1MB/s
# Requirement already satisfied: urllib3<1.23.0,>=1.15 in /usr/local/lib/python3.6/dist-packages (from kaggle) (1.22)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.6/dist-packages (from kaggle) (1.11.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.6/dist-packages (from kaggle) (2018.10.15)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.6/dist-packages (from kaggle) (2.5.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from kaggle) (2.18.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from kaggle) (4.27.0)
# Collecting python-slugify (from kaggle)
#   Downloading https://files.pythonhosted.org/packages/00/ad/c778a6df614b6217c30fe80045b365bfa08b5dd3cb02e8b37a6d25126781/python-slugify-1.2.6.tar.gz
# Requirement already satisfied: idna<2.7,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->kaggle) (2.6)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->kaggle) (3.0.4)
# Collecting Unidecode>=0.04.16 (from python-slugify->kaggle)
#   Downloading https://files.pythonhosted.org/packages/59/ef/67085e30e8bbcdd76e2f0a4ad8151c13a2c5bce77c85f8cad6e1f16fb141/Unidecode-1.0.22-py2.py3-none-any.whl (235kB)
#     100% |████████████████████████████████| 235kB 7.1MB/s
# Building wheels for collected packages: kaggle, python-slugify
# done
#   Stored in directory: /root/.cache/pip/wheels/44/2c/df/22a6eeb780c36c28190faef6252b739fdc47145fd87a6642d4
# done
#   Stored in directory: /root/.cache/pip/wheels/e3/65/da/2045deea3098ed7471eca0e2460cfbd3fdfe8c1d6fa6fcac92
# Successfully built kaggle python-slugify
# Installing collected packages: Unidecode, python-slugify, kaggle
# Successfully installed Unidecode-1.0.22 kaggle-1.4.7.1 python-slugify-1.2.6
# Downloading train.csv to /content
#  94% 69.0M/73.2M [00:01<00:00, 33.0MB/s]
# 100% 73.2M/73.2M [00:01<00:00, 66.1MB/s]
# Downloading test.csv to /content
#  68% 33.0M/48.8M [00:00<00:00, 30.2MB/s]
# 100% 48.8M/48.8M [00:00<00:00, 68.5MB/s]
# Downloading sample_submission.csv to /content
#   0% 0.00/235k [00:00<?, ?B/s]
# 100% 235k/235k [00:00<00:00, 75.9MB/s]

# %% [markdown]
# Chainerを使えるように必要なものをinstallします

# %%
# !curl https://colab.chainer.org/install | sh -

# %% [markdown]
# 必要なモジュールをimportします

# %%
import argparse
import copy
import chainer
import chainer.functions as F
import chainer.links as L
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from chainer import cuda, training, reporter, Variable, serializers
from chainer.training import trainer, extensions
from chainer.dataset import convert
from chainer.datasets import tuple_dataset
from chainer.dataset import iterator as iterator_module
from chainer import optimizer as optimizer_module

# %% [markdown]
# argparserを設定します

# %%
parser = argparse.ArgumentParser(description='MNIST')
parser.add_argument('--init', '-i', default=0, type=int)
parser.add_argument('--gpu', '-g', default=0, type=int)
parser.add_argument('--out', '-o', default='result')
parser.add_argument('--epoch', '-e', default=30, type=int)
parser.add_argument('--batchsize', '-b', default=100, type=int)
parser.add_argument('--file_name', '-f', default='test', type=str)
parser.add_argument('--snapshot', '-s', default=10, type=int)
parser.add_argument('--withlabel', '-wl', default=False, type=bool)
args = parser.parse_args()

# %% [markdown]
# データセットをロードする関数を定義します

# %%
def Load_Dataset(withlabel=True, conv=True):
    input = pd.read_csv("train.csv")
    data = input.values
    #画像とラベルに分ける．画像は255で割って0~1に正規化
    img = (data[:,1:]/255.0).astype(np.float32)
    label = (data[:,:1].flatten()).astype(np.int32)
    #imgを28x28にreshape
    if conv:
        img = np.reshape(img, (-1, 1, 28, 28))
    #trainとtestのしきい値を決める
    threshhold = np.int32(len(img)*0.8)
    #tupledatasetを作る
    if withlabel:
        train = tuple_dataset.TupleDataset(img[0:threshhold], label[0:threshhold])
        test = tuple_dataset.TupleDataset(img[threshhold:], label[threshhold:])
    else:
        train = tuple_dataset.TupleDataset(img[0:threshhold],)
        test = tuple_dataset.TupleDataset(img[threshhold:],)
    return train, test

# %% [markdown]
# Trainerで使うEvaluatorやUpdaterを作ります

# %%
class MyEvaluator(extensions.Evaluator):
    def __init__(self, iterator, CLS,
        converter=convert.concat_examples,device=0, eval_hook=None,
        eval_func=None):
        if isinstance(iterator, iterator_module.Iterator):
            iterator = {'main': iterator}
        self._iterators = iterator
        self._targets = {'main':CLS}

        self.converter = converter
        self.device = device
        self.eval_hook = eval_hook

    def evaluate(self):
        iterator = self._iterators['main']
        self.CLS = self._targets['main']
        xp = np if int(self.device) == -1 else cuda.cupy
        it = copy.copy(iterator)
        summary = reporter.DictSummary()
        for batch in it:
            observation = {}
            with reporter.report_scope(observation):
                input = self.converter(batch, self.device)
                x_batch = xp.array(input[0])
                t_batch = xp.array(input[1])
                self.loss = 0
                self.acc = 0
                with chainer.using_config('train', False):
                    y = self.CLS(x_batch, softmax=False)
                    self.loss = F.softmax_cross_entropy(y, t_batch)
                    self.acc = F.accuracy(y, t_batch)
                observation['val/loss'] = self.loss
                observation['val/acc'] = self.acc
            summary.add(observation)
        return summary.compute_mean()

# %%
class MyUpdater(training.StandardUpdater):
    def __init__(self, iterator, CLS, opt,
        converter=convert.concat_examples,device=0):
        if isinstance(iterator, iterator_module.Iterator):
            iterator = {'main':iterator}
        self._iterators = iterator
        self.CLS = CLS
        self._optimizers = {"main":opt}
        self.converter = convert.concat_examples
        self.device = device
        self.iteration = 0

    def update_core(self):
        """lossを計算"""
        iterator = self._iterators['main'].next()
        input = self.converter(iterator, self.device)
        xp = np if int(self.device) == -1 else cuda.cupy
        x_batch = xp.array(input[0])
        t_batch = xp.array(input[1])
        self.loss = 0
        self.acc = 0
        #計算開始
        y = self.CLS(x_batch, softmax=False)
        self.loss = F.softmax_cross_entropy(y, t_batch)
        self.acc = F.accuracy(y, t_batch)
        self._optimizers["main"].target.cleargrads()
        self.loss.backward()
        self._optimizers["main"].update()
        reporter.report({'main/loss':self.loss, 'main/acc':self.acc})

# %% [markdown]
# 今回使うネットワークは畳込み3層+全結合2層です

# %%
class CLS(chainer.Chain):
    #入力は1チャネル白黒画像
    def __init__(self):
        super(CLS, self).__init__()
        with self.init_scope():
            self.conv1 = L.Convolution2D(None, 8, 3, pad=1)
            self.ebn1 = L.BatchNormalization(8)
            self.conv2 = L.Convolution2D(8, 16, 3, pad=1)
            self.ebn2 = L.BatchNormalization(16)
            self.conv3 = L.Convolution2D(16, 32, 3, pad=1)
            self.fc1 = L.Linear(None, 1000)
            self.fc2 = L.Linear(1000, 10)

    def __call__(self, x, softmax=True):
        return self.cls(x, softmax)
    def cls(self, x, softmax=True):
        h = F.leaky_relu(self.ebn1(self.conv1(x)))
        h = F.leaky_relu(self.ebn2(self.conv2(h)))
        h = F.leaky_relu(self.conv3(h))
        h = F.leaky_relu(self.fc1(h))
        h = F.leaky_relu(self.fc2(h))
        if softmax:
            return F.softmax(h)
        else:
            return h

# %% [markdown]
# Trainerを使って学習していきます．

# %%
print('#GPU:{}'.format(args.gpu))
print('#minibatch-size:{}'.format(args.batchsize))
print('#epoch:{}'.format(args.epoch))
print('')

CLS.to_gpu()
print('Loading')
train, test = Load_Dataset(withlabel=True, conv=True)
#train, test = chainer.datasets.mnist.get_mnist(withlabel=True, ndim=3)
print('Loaded')
def make_optimizer(model, alpha=0.0002, beta1=0.9, beta2=0.999):
    #optimizer = chainer.optimizers.MomentumSGD(lr=0.01)
    optimizer = chainer.optimizers.Adam(alpha=alpha, beta1=beta1, beta2=beta2)
    optimizer.setup(model)
    optimizer.add_hook(chainer.optimizer.WeightDecay(0.0001))
    return optimizer
opt = make_optimizer(CLS)
#Laod the dataset
train_iter = chainer.iterators.SerialIterator(train, args.batchsize)
test_iter = chainer.iterators.SerialIterator(test, args.batchsize,
                                            repeat=False, shuffle=False)
updater = MyUpdater(train_iter, CLS, opt, device=args.gpu)
trainer = training.Trainer(updater, (args.epoch, 'epoch'),
    out="{}/b{}".format(args.out, args.batchsize))
#trainer.extend(extensions.observe_lr())
trainer.extend(MyEvaluator(test_iter, CLS,
    device=args.gpu))
trainer.extend(extensions.snapshot_object(CLS,
    filename="CLS_epoch_{.updater.epoch}"), trigger=(args.snapshot, 'epoch'))
#trainer.extend(extensions.ExponentialShift('lr', 0.1), trigger=(30, 'epoch'))
trainer.extend(extensions.LogReport())
trainer.extend(extensions.PrintReport(
    ['epoch', 'main/loss', 'main/acc', 'val/loss',
    'val/acc', 'elapsed_time', 'lr']))
trainer.extend(extensions.ProgressBar())

trainer.run()
del trainer
# Out:
# #GPU:0
# #minibatch-size:100
# #epoch:30
#
# Loading
# Loaded
# epoch       main/loss   main/acc    val/loss    val/acc     elapsed_time  lr
#      total [..................................................]  0.99%
# this epoch [##############....................................] 29.76%
#        100 iter, 0 epoch / 30 epochs
#        inf iters/sec. Estimated time to finish: 0:00:00.
#      total [..................................................]  1.98%
# this epoch [#############################.....................] 59.52%
#        200 iter, 0 epoch / 30 epochs
#     33.506 iters/sec. Estimated time to finish: 0:04:54.876108.
#      total [#.................................................]  2.98%
# this epoch [############################################......] 89.29%
#        300 iter, 0 epoch / 30 epochs
#     33.499 iters/sec. Estimated time to finish: 0:04:51.947015.
# 1           0.0667201   0.981608    0.053135    0.983215    10.8158
#      total [#.................................................]  3.97%
# this epoch [#########.........................................] 19.05%
#        400 iter, 1 epoch / 30 epochs
#     31.154 iters/sec. Estimated time to finish: 0:05:10.712702.
#      total [##................................................]  4.96%
# this epoch [########################..........................] 48.81%
#        500 iter, 1 epoch / 30 epochs
#     31.701 iters/sec. Estimated time to finish: 0:05:02.197029.
#      total [##................................................]  5.95%
# this epoch [#######################################...........] 78.57%
#        600 iter, 1 epoch / 30 epochs
#      32.02 iters/sec. Estimated time to finish: 0:04:56.066024.
# 2           0.0196515   0.994583    0.0585355   0.982381    21.5442
#      total [###...............................................]  6.94%
# this epoch [####..............................................]  8.33%
#        700 iter, 2 epoch / 30 epochs
#     31.112 iters/sec. Estimated time to finish: 0:05:01.491194.
#      total [###...............................................]  7.94%
# this epoch [###################...............................] 38.10%
#        800 iter, 2 epoch / 30 epochs
#     31.412 iters/sec. Estimated time to finish: 0:04:55.433024.
#      total [####..............................................]  8.93%
# this epoch [#################################.................] 67.86%
#        900 iter, 2 epoch / 30 epochs
#     31.639 iters/sec. Estimated time to finish: 0:04:50.149173.
#      total [####..............................................]  9.92%
# this epoch [################################################..] 97.62%
#       1000 iter, 2 epoch / 30 epochs
#     31.815 iters/sec. Estimated time to finish: 0:04:45.404059.
# 3           0.0105481   0.997292    0.0516083   0.984762    32.297
#      total [#####.............................................] 10.91%
# this epoch [#############.....................................] 27.38%
#       1100 iter, 3 epoch / 30 epochs
#     31.286 iters/sec. Estimated time to finish: 0:04:47.025441.
#      total [#####.............................................] 11.90%
# this epoch [############################......................] 57.14%
#       1200 iter, 3 epoch / 30 epochs
#     31.457 iters/sec. Estimated time to finish: 0:04:42.290322.
#      total [######............................................] 12.90%
# this epoch [###########################################.......] 86.90%
#       1300 iter, 3 epoch / 30 epochs
#     31.605 iters/sec. Estimated time to finish: 0:04:37.808342.
# 4           0.00566019  0.998809    0.0522737   0.985953    43.066
#      total [######............................................] 13.89%
# this epoch [########..........................................] 16.67%
#       1400 iter, 4 epoch / 30 epochs
#     31.215 iters/sec. Estimated time to finish: 0:04:38.068911.
#      total [#######...........................................] 14.88%
# this epoch [#######################...........................] 46.43%
#       1500 iter, 4 epoch / 30 epochs
#     31.352 iters/sec. Estimated time to finish: 0:04:33.669304.
#      total [#######...........................................] 15.87%
# this epoch [######################################............] 76.19%
#       1600 iter, 4 epoch / 30 epochs
#     31.472 iters/sec. Estimated time to finish: 0:04:29.442532.
# 5           0.00314806  0.999494    0.057609    0.984167    53.8365
#      total [########..........................................] 16.87%
# this epoch [##................................................]  5.95%
#       1700 iter, 5 epoch / 30 epochs
#     31.154 iters/sec. Estimated time to finish: 0:04:28.985159.
#      total [########..........................................] 17.86%
# this epoch [#################.................................] 35.71%
#       1800 iter, 5 epoch / 30 epochs
#     31.281 iters/sec. Estimated time to finish: 0:04:24.697212.
#      total [#########.........................................] 18.85%
# this epoch [################################..................] 65.48%
#       1900 iter, 5 epoch / 30 epochs
#     31.386 iters/sec. Estimated time to finish: 0:04:20.623018.
#      total [#########.........................................] 19.84%
# this epoch [###############################################...] 95.24%
#       2000 iter, 5 epoch / 30 epochs
#     31.483 iters/sec. Estimated time to finish: 0:04:16.646417.
# 6           0.00531091  0.998571    0.0655749   0.981548    64.5989
#      total [##########........................................] 20.83%
# this epoch [############......................................] 25.00%
#       2100 iter, 6 epoch / 30 epochs
#     31.237 iters/sec. Estimated time to finish: 0:04:15.465666.
#      total [##########........................................] 21.83%
# this epoch [###########################.......................] 54.76%
#       2200 iter, 6 epoch / 30 epochs
#      31.33 iters/sec. Estimated time to finish: 0:04:11.519964.
#      total [###########.......................................] 22.82%
# this epoch [##########################################........] 84.52%
#       2300 iter, 6 epoch / 30 epochs
#      31.41 iters/sec. Estimated time to finish: 0:04:07.688149.
# 7           0.00799944  0.997411    0.0704202   0.979881    75.3788
#      total [###########.......................................] 23.81%
# this epoch [#######...........................................] 14.29%
#       2400 iter, 7 epoch / 30 epochs
#     31.199 iters/sec. Estimated time to finish: 0:04:06.161750.
#      total [############......................................] 24.80%
# this epoch [######################............................] 44.05%
#       2500 iter, 7 epoch / 30 epochs
#      31.28 iters/sec. Estimated time to finish: 0:04:02.329521.
#      total [############......................................] 25.79%
# this epoch [####################################..............] 73.81%
#       2600 iter, 7 epoch / 30 epochs
#     31.354 iters/sec. Estimated time to finish: 0:03:58.565947.
# 8           0.00992429  0.996429    0.0651914   0.983929    86.1545
#      total [#############.....................................] 26.79%
# this epoch [#.................................................]  3.57%
#       2700 iter, 8 epoch / 30 epochs
#     31.117 iters/sec. Estimated time to finish: 0:03:57.166393.
#      total [#############.....................................] 27.78%
# this epoch [################..................................] 33.33%
#       2800 iter, 8 epoch / 30 epochs
#     31.243 iters/sec. Estimated time to finish: 0:03:53.011551.
#      total [##############....................................] 28.77%
# this epoch [###############################...................] 63.10%
#       2900 iter, 8 epoch / 30 epochs
#     31.312 iters/sec. Estimated time to finish: 0:03:49.306892.
#      total [##############....................................] 29.76%
# this epoch [##############################################....] 92.86%
#       3000 iter, 8 epoch / 30 epochs
#     31.375 iters/sec. Estimated time to finish: 0:03:45.660651.
# 9           0.00539144  0.998304    0.0720394   0.983453    96.928
#      total [###############...................................] 30.75%
# this epoch [###########.......................................] 22.62%
#       3100 iter, 9 epoch / 30 epochs
#     31.214 iters/sec. Estimated time to finish: 0:03:43.617391.
#      total [###############...................................] 31.75%
# this epoch [##########################........................] 52.38%
#       3200 iter, 9 epoch / 30 epochs
#     31.274 iters/sec. Estimated time to finish: 0:03:39.993640.
#      total [################..................................] 32.74%
# this epoch [#########################################.........] 82.14%
#       3300 iter, 9 epoch / 30 epochs
#      31.33 iters/sec. Estimated time to finish: 0:03:36.405289.
# 10          0.00305647  0.999048    0.0633357   0.984048    107.709
#      total [################..................................] 33.73%
# this epoch [#####.............................................] 11.90%
#       3400 iter, 10 epoch / 30 epochs
#     29.749 iters/sec. Estimated time to finish: 0:03:44.545714.
#      total [#################.................................] 34.72%
# this epoch [####################..............................] 41.67%
#       3500 iter, 10 epoch / 30 epochs
#     29.841 iters/sec. Estimated time to finish: 0:03:40.501058.
#      total [#################.................................] 35.71%
# this epoch [###################################...............] 71.43%
#       3600 iter, 10 epoch / 30 epochs
#     29.931 iters/sec. Estimated time to finish: 0:03:36.500226.
# 11          0.00224905  0.999315    0.0734231   0.984048    123.595
#      total [##################................................] 36.71%
# this epoch [..................................................]  1.19%
#       3700 iter, 11 epoch / 30 epochs
#     29.782 iters/sec. Estimated time to finish: 0:03:34.225155.
#      total [##################................................] 37.70%
# this epoch [###############...................................] 30.95%
#       3800 iter, 11 epoch / 30 epochs
#     29.931 iters/sec. Estimated time to finish: 0:03:29.812862.
#      total [###################...............................] 38.69%
# this epoch [##############################....................] 60.71%
#       3900 iter, 11 epoch / 30 epochs
#      30.01 iters/sec. Estimated time to finish: 0:03:25.933908.
#      total [###################...............................] 39.68%
# this epoch [#############################################.....] 90.48%
#       4000 iter, 11 epoch / 30 epochs
#     30.085 iters/sec. Estimated time to finish: 0:03:22.096354.
# 12          0.00222035  0.999345    0.070055    0.982262    134.369
#      total [####################..............................] 40.67%
# this epoch [##########........................................] 20.24%
#       4100 iter, 12 epoch / 30 epochs
#     30.004 iters/sec. Estimated time to finish: 0:03:19.306500.
#      total [####################..............................] 41.67%
# this epoch [#########################.........................] 50.00%
#       4200 iter, 12 epoch / 30 epochs
#     30.077 iters/sec. Estimated time to finish: 0:03:15.499879.
#      total [#####################.............................] 42.66%
# this epoch [#######################################...........] 79.76%
#       4300 iter, 12 epoch / 30 epochs
#     30.144 iters/sec. Estimated time to finish: 0:03:11.746730.
# 13          0.00342838  0.998839    0.0836157   0.9825      145.149
#      total [#####################.............................] 43.65%
# this epoch [####..............................................]  9.52%
#       4400 iter, 13 epoch / 30 epochs
#     30.067 iters/sec. Estimated time to finish: 0:03:08.912192.
#      total [######################............................] 44.64%
# this epoch [###################...............................] 39.29%
#       4500 iter, 13 epoch / 30 epochs
#     30.132 iters/sec. Estimated time to finish: 0:03:05.184818.
#      total [######################............................] 45.63%
# this epoch [##################################................] 69.05%
#       4600 iter, 13 epoch / 30 epochs
#     30.194 iters/sec. Estimated time to finish: 0:03:01.492666.
#      total [#######################...........................] 46.63%
# this epoch [#################################################.] 98.81%
#       4700 iter, 13 epoch / 30 epochs
#     30.255 iters/sec. Estimated time to finish: 0:02:57.822047.
# 14          0.0126738   0.995714    0.0851085   0.980119    155.933
#      total [#######################...........................] 47.62%
# this epoch [##############....................................] 28.57%
#       4800 iter, 14 epoch / 30 epochs
#     30.182 iters/sec. Estimated time to finish: 0:02:54.936810.
#      total [########################..........................] 48.61%
# this epoch [#############################.....................] 58.33%
#       4900 iter, 14 epoch / 30 epochs
#      30.24 iters/sec. Estimated time to finish: 0:02:51.296746.
#      total [########################..........................] 49.60%
# this epoch [############################################......] 88.10%
#       5000 iter, 14 epoch / 30 epochs
#     30.295 iters/sec. Estimated time to finish: 0:02:47.686709.
# 15          0.00590752  0.998125    0.0726919   0.982143    166.718
#      total [#########################.........................] 50.60%
# this epoch [########..........................................] 17.86%
#       5100 iter, 15 epoch / 30 epochs
#     30.225 iters/sec. Estimated time to finish: 0:02:44.766480.
#      total [#########################.........................] 51.59%
# this epoch [#######################...........................] 47.62%
#       5200 iter, 15 epoch / 30 epochs
#     30.278 iters/sec. Estimated time to finish: 0:02:41.174111.
#      total [##########################........................] 52.58%
# this epoch [######################################............] 77.38%
#       5300 iter, 15 epoch / 30 epochs
#     30.329 iters/sec. Estimated time to finish: 0:02:37.604447.
# 16          0.00145329  0.999821    0.0604992   0.984762    177.51
#      total [##########################........................] 53.57%
# this epoch [###...............................................]  7.14%
#       5400 iter, 16 epoch / 30 epochs
#     30.263 iters/sec. Estimated time to finish: 0:02:34.644164.
#      total [###########################.......................] 54.56%
# this epoch [##################................................] 36.90%
#       5500 iter, 16 epoch / 30 epochs
#     30.315 iters/sec. Estimated time to finish: 0:02:31.082332.
#      total [###########################.......................] 55.56%
# this epoch [#################################.................] 66.67%
#       5600 iter, 16 epoch / 30 epochs
#     30.363 iters/sec. Estimated time to finish: 0:02:27.550139.
#      total [############################......................] 56.55%
# this epoch [################################################..] 96.43%
#       5700 iter, 16 epoch / 30 epochs
#      30.41 iters/sec. Estimated time to finish: 0:02:24.032777.
# 17          0.00083922  0.999792    0.0537659   0.986786    188.286
#      total [############################......................] 57.54%
# this epoch [#############.....................................] 26.19%
#       5800 iter, 17 epoch / 30 epochs
#     30.347 iters/sec. Estimated time to finish: 0:02:21.034880.
#      total [#############################.....................] 58.53%
# this epoch [###########################.......................] 55.95%
#       5900 iter, 17 epoch / 30 epochs
#     30.392 iters/sec. Estimated time to finish: 0:02:17.534215.
#      total [#############################.....................] 59.52%
# this epoch [##########################################........] 85.71%
#       6000 iter, 17 epoch / 30 epochs
#     30.437 iters/sec. Estimated time to finish: 0:02:14.048930.
# 18          0.00185511  0.999405    0.0568954   0.986071    199.065
#      total [##############################....................] 60.52%
# this epoch [#######...........................................] 15.48%
#       6100 iter, 18 epoch / 30 epochs
#     30.375 iters/sec. Estimated time to finish: 0:02:11.027029.
#      total [##############################....................] 61.51%
# this epoch [######################............................] 45.24%
#       6200 iter, 18 epoch / 30 epochs
#     30.419 iters/sec. Estimated time to finish: 0:02:07.553950.
#      total [###############################...................] 62.50%
# this epoch [#####################################.............] 75.00%
#       6300 iter, 18 epoch / 30 epochs
#      30.46 iters/sec. Estimated time to finish: 0:02:04.096914.
# 19          0.00690898  0.997619    0.0881835   0.978453    209.85
#      total [###############################...................] 63.49%
# this epoch [##................................................]  4.76%
#       6400 iter, 19 epoch / 30 epochs
#      30.39 iters/sec. Estimated time to finish: 0:02:01.091489.
#      total [################################..................] 64.48%
# this epoch [#################.................................] 34.52%
#       6500 iter, 19 epoch / 30 epochs
#     30.442 iters/sec. Estimated time to finish: 0:01:57.599105.
#      total [################################..................] 65.48%
# this epoch [################################..................] 64.29%
#       6600 iter, 19 epoch / 30 epochs
#     30.482 iters/sec. Estimated time to finish: 0:01:54.167285.
#      total [#################################.................] 66.47%
# this epoch [###############################################...] 94.05%
#       6700 iter, 19 epoch / 30 epochs
#      30.52 iters/sec. Estimated time to finish: 0:01:50.747662.
# 20          0.00470658  0.998631    0.0645982   0.985       220.621
#      total [#################################.................] 67.46%
# this epoch [###########.......................................] 23.81%
#       6800 iter, 20 epoch / 30 epochs
#      29.78 iters/sec. Estimated time to finish: 0:01:50.142118.
#      total [##################################................] 68.45%
# this epoch [##########################........................] 53.57%
#       6900 iter, 20 epoch / 30 epochs
#     29.826 iters/sec. Estimated time to finish: 0:01:46.619613.
#      total [##################################................] 69.44%
# this epoch [#########################################.........] 83.33%
#       7000 iter, 20 epoch / 30 epochs
#     29.871 iters/sec. Estimated time to finish: 0:01:43.111678.
# 21          0.00156889  0.999554    0.0649168   0.986548    236.457
#      total [###################################...............] 70.44%
# this epoch [######............................................] 13.10%
#       7100 iter, 21 epoch / 30 epochs
#     29.828 iters/sec. Estimated time to finish: 0:01:39.905819.
#      total [###################################...............] 71.43%
# this epoch [#####################.............................] 42.86%
#       7200 iter, 21 epoch / 30 epochs
#     29.871 iters/sec. Estimated time to finish: 0:01:36.414269.
#      total [####################################..............] 72.42%
# this epoch [####################################..............] 72.62%
#       7300 iter, 21 epoch / 30 epochs
#     29.913 iters/sec. Estimated time to finish: 0:01:32.934838.
# 22          0.000701652  0.999881    0.0567523   0.987738    247.225
#      total [####################################..............] 73.41%
# this epoch [#.................................................]  2.38%
#       7400 iter, 22 epoch / 30 epochs
#     29.848 iters/sec. Estimated time to finish: 0:01:29.787295.
#      total [#####################################.............] 74.40%
# this epoch [################..................................] 32.14%
#       7500 iter, 22 epoch / 30 epochs
#     29.914 iters/sec. Estimated time to finish: 0:01:26.247496.
#      total [#####################################.............] 75.40%
# this epoch [##############################....................] 61.90%
#       7600 iter, 22 epoch / 30 epochs
#     29.954 iters/sec. Estimated time to finish: 0:01:22.792960.
#      total [######################################............] 76.39%
# this epoch [#############################################.....] 91.67%
#       7700 iter, 22 epoch / 30 epochs
#     29.994 iters/sec. Estimated time to finish: 0:01:19.350518.
# 23          0.000235081  1           0.0528347   0.988095    258.003
#      total [######################################............] 77.38%
# this epoch [##########........................................] 21.43%
#       7800 iter, 23 epoch / 30 epochs
#     29.953 iters/sec. Estimated time to finish: 0:01:16.119885.
#      total [#######################################...........] 78.37%
# this epoch [#########################.........................] 51.19%
#       7900 iter, 23 epoch / 30 epochs
#      29.99 iters/sec. Estimated time to finish: 0:01:12.689842.
#      total [#######################################...........] 79.37%
# this epoch [########################################..........] 80.95%
#       8000 iter, 23 epoch / 30 epochs
#     30.027 iters/sec. Estimated time to finish: 0:01:09.270706.
# 24          0.000224545  0.99997     0.0545346   0.987024    268.792
#      total [########################################..........] 80.36%
# this epoch [#####.............................................] 10.71%
#       8100 iter, 24 epoch / 30 epochs
#     29.988 iters/sec. Estimated time to finish: 0:01:06.026144.
#      total [########################################..........] 81.35%
# this epoch [####################..............................] 40.48%
#       8200 iter, 24 epoch / 30 epochs
#     30.024 iters/sec. Estimated time to finish: 0:01:02.616524.
#      total [#########################################.........] 82.34%
# this epoch [###################################...............] 70.24%
#       8300 iter, 24 epoch / 30 epochs
#     30.059 iters/sec. Estimated time to finish: 0:00:59.216408.
# 25          0.00493382  0.99866     0.0947647   0.979881    279.571
#      total [#########################################.........] 83.33%
# this epoch [..................................................]  0.00%
#       8400 iter, 25 epoch / 30 epochs
#     29.986 iters/sec. Estimated time to finish: 0:00:56.026532.
#      total [##########################################........] 84.33%
# this epoch [##############....................................] 29.76%
#       8500 iter, 25 epoch / 30 epochs
#     30.055 iters/sec. Estimated time to finish: 0:00:52.570124.
#      total [##########################################........] 85.32%
# this epoch [#############################.....................] 59.52%
#       8600 iter, 25 epoch / 30 epochs
#     30.089 iters/sec. Estimated time to finish: 0:00:49.186794.
#      total [###########################################.......] 86.31%
# this epoch [############################################......] 89.29%
#       8700 iter, 25 epoch / 30 epochs
#     30.122 iters/sec. Estimated time to finish: 0:00:45.814074.
# 26          0.0210235   0.992976    0.0647873   0.984048    290.364
#      total [###########################################.......] 87.30%
# this epoch [#########.........................................] 19.05%
#       8800 iter, 26 epoch / 30 epochs
#     30.084 iters/sec. Estimated time to finish: 0:00:42.547154.
#      total [############################################......] 88.29%
# this epoch [########################..........................] 48.81%
#       8900 iter, 26 epoch / 30 epochs
#     30.116 iters/sec. Estimated time to finish: 0:00:39.181389.
#      total [############################################......] 89.29%
# this epoch [#######################################...........] 78.57%
#       9000 iter, 26 epoch / 30 epochs
#     30.149 iters/sec. Estimated time to finish: 0:00:35.822139.
# 27          0.00422963  0.998542    0.0663717   0.984405    301.14
#      total [#############################################.....] 90.28%
# this epoch [####..............................................]  8.33%
#       9100 iter, 27 epoch / 30 epochs
#     30.113 iters/sec. Estimated time to finish: 0:00:32.544373.
#      total [#############################################.....] 91.27%
# this epoch [###################...............................] 38.10%
#       9200 iter, 27 epoch / 30 epochs
#     30.144 iters/sec. Estimated time to finish: 0:00:29.193664.
#      total [##############################################....] 92.26%
# this epoch [#################################.................] 67.86%
#       9300 iter, 27 epoch / 30 epochs
#     30.174 iters/sec. Estimated time to finish: 0:00:25.850385.
#      total [##############################################....] 93.25%
# this epoch [################################################..] 97.62%
#       9400 iter, 27 epoch / 30 epochs
#     30.204 iters/sec. Estimated time to finish: 0:00:22.513555.
# 28          0.000816298  0.999911    0.0551664   0.987262    311.918
#      total [###############################################...] 94.25%
# this epoch [#############.....................................] 27.38%
#       9500 iter, 28 epoch / 30 epochs
#     30.168 iters/sec. Estimated time to finish: 0:00:19.225820.
#      total [###############################################...] 95.24%
# this epoch [############################......................] 57.14%
#       9600 iter, 28 epoch / 30 epochs
#     30.197 iters/sec. Estimated time to finish: 0:00:15.895721.
#      total [################################################..] 96.23%
# this epoch [###########################################.......] 86.90%
#       9700 iter, 28 epoch / 30 epochs
#     30.225 iters/sec. Estimated time to finish: 0:00:12.572299.
# 29          0.000236998  1           0.0564152   0.987262    322.713
#      total [################################################..] 97.22%
# this epoch [########..........................................] 16.67%
#       9800 iter, 29 epoch / 30 epochs
#      30.19 iters/sec. Estimated time to finish: 0:00:09.274657.
#      total [#################################################.] 98.21%
# this epoch [#######################...........................] 46.43%
#       9900 iter, 29 epoch / 30 epochs
#     30.218 iters/sec. Estimated time to finish: 0:00:05.956739.
#      total [#################################################.] 99.21%
# this epoch [######################################............] 76.19%
#      10000 iter, 29 epoch / 30 epochs
#     30.246 iters/sec. Estimated time to finish: 0:00:02.644974.
# 30          0.000162787  1           0.0544654   0.987619    333.494

# %% [markdown]
# 30epochだけ学習しました．Predictしていきましょう．

# %%
def Load_testDataset(withlabel=False, conv=True):
    input = pd.read_csv("test.csv")
    data = input.values
    #画像とラベルに分ける．画像は255で割って0~1に正規化
    img = (data/255.0).astype(np.float32)
    #imgを28x28にreshape
    if conv:
        img = np.reshape(img, (-1, 1, 28, 28))
    #tupledatasetを作る
    test = tuple_dataset.TupleDataset(img,)
    return test

# %% [markdown]
# まずはmnistデータセットを使って正答率を見ます．

# %%
#load model
serializers.load_npz('result/b{}/CLS_epoch_{}'.format(args.batchsize,
args.epoch), CLS)
#dataset
_,test = chainer.datasets.get_mnist(withlabel=True, ndim=3)
success = 0
fail = 0
#calc
for i in range(1000):
    x,t = test[i]
    CLS.to_cpu()
    with chainer.using_config('train', False), \
        chainer.using_config('enable_backprop', False):
        y = CLS(x[None, ...]).data.argmax(axis=1)[0]
    #z = model.predictor(x[None, ...]).data#softmax全体を表示
    if(y==t):
        success+=1
    else:
        fail+=1
    #progress
    if(i%100==0):
        print(i)
#out
print("result: success={0}, fail={1}".format(success,fail))
print("ratio = ",success/1000)
# Out:
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# result: success=996, fail=4
# ratio =  0.996

# %% [markdown]
# 最後に提出用のcsvファイルを作成します

# %%
def Predict_num():
    serializers.load_npz('result/b{}/CLS_epoch_{}'.format(args.batchsize,
    args.epoch), CLS)
    test = Load_testDataset()
    test_labels = np.zeros(1).astype(np.int32)
    for i in range(0, 28000):
        x = test[i][0]
        #plt.imshow(x.reshape(28,28), cmap='gray')
        #plt.show()
        with chainer.using_config('train', False), \
            chainer.using_config('enable_backprop', False):
            y = CLS(x[None, ...]).data.argmax(axis=1)[0]
        test_labels = np.append(test_labels, y)
        if(i%1000==0):
            print(i)
        #print("predict:", y)
    test_labels = test_labels[1:]
    return test_labels

# %% [markdown]
# コメントアウトしているpltとprintを使うと画像と推論されたラベルがわかる．

# %%
test_labels = Predict_num()
submmission = pd.DataFrame(data={'ImageId':(np.arange(test_labels.shape[0])+1),
    'Label':test_labels})
submmission.to_csv('submission.csv', index=False)
submmission.tail()
# Out:
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
#        ImageId  Label
# 27995    27996      9
# 27996    27997      7
# 27997    27998      3
# 27998    27999      9
# 27999    28000      2

# %% [markdown]
# 終わりです
